# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
data_com_buisness = pd.read_csv("C:/Users/purva.redkar/Downloads/yelp_dataset/yelp_business_merged.csv")

# %%
np.random.seed(500)
data_com_buisness['text'].dropna(inplace=True)
data_com_buisness['text'] = [entry.lower() for entry in data_com_buisness['text']]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import re

import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")
def cleanHtml(sentence):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(sentence))
    return cleantext


def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned


def keepAlpha(sentence):
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

data_com_buisness['text_1'] = data_com_buisness['text'].str.lower()
data_com_buisness['text_1'] = data_com_buisness['text_1'].apply(cleanHtml)
data_com_buisness['text_1'] = data_com_buisness['text_1'].apply(cleanPunc)
data_com_buisness['text_1'] = data_com_buisness['text_1'].apply(keepAlpha)
data_com_buisness.head()

stop_words = set(stopwords.words('english'))
stop_words.update(['zero','one','two','three','four','five','six','seven','eight','nine','ten','may','also','across','among','beside','however','yet','within','lous'])
re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)
def removeStopWords(sentence):
    global re_stop_words
    return re_stop_words.sub(" ", sentence)

data_com_buisness['text_1'] = data_com_buisness['text'].apply(removeStopWords)
data_com_buisness.head()

stemmer = SnowballStemmer("english")
def stemming(sentence):
    stemSentence = ""
    for word in sentence.split():
        stem = stemmer.stem(word)
        stemSentence += stem
        stemSentence += " "
    stemSentence = stemSentence.strip()
    return stemSentence

data_com_buisness['text_1'] = data_com_buisness['text_1'].apply(stemming)
data_com_buisness.head()
# Out:
#               business_id                        name state  stars_x  \
# 0  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 1  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 2  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 3  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
#
#    review_count                                         categories  \
# 0           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 1           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 2           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 3           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 4           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
#
#                 review_id                 user_id  stars_y        date  \
# 0  rnvu74aNIPn93Z9Ue11Epw  bgtr7jOlALe8ay4g7pnf4A        4  2016-05-05
# ...

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(data_com_buisness['text_1'],data_com_buisness['stars_y'],test_size=0.3)

# %%
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(data_com_buisness['text_1'])
print(Train_X_Tfidf)

# %%
print(Tfidf_vect.vocabulary_)
# Out:
# {'alway': 205, 'enjoy': 1561, 'time': 4508, 'brick': 635, 'hous': 2236, 'food': 1839, 'cocktail': 990, 'never': 2984, 'disappoint': 1375, 'perfect': 3275, 'work': 4935, 'summer': 4326, 'staff': 4199, 'polit': 3393, 'decor': 1282, 'beautiful': 467, 'must': 2937, 'place': 3349, '1st': 24, 'came': 744, 'bc': 456, 'loui': 2655, 'closed': 971, 'burger': 689, 'salad': 3789, 'ice': 2266, 'tea': 4419, '36': 57, '70': 78, 'still': 4248, 'hungry': 2256, 'good': 2004, 'bun': 686, 'liter': 2616, 'got': 2014, '14': 15, 'shoe': 3958, 'string': 4280, 'fri': 1887, 'ridicul': 3721, 'huge': 2246, 'plate': 3358, 'much': 2920, 'empti': 1543, 'space': 4142, 'back': 390, 'wors': 4945, 'servic': 3913, 'ever': 1612, 'andi': 223, 'use': 4719, 'server': 3911, 'job': 2427, 'aw': 368, 'service': 3914, 'waitress': 4812, 'profession': 3481, 'rude': 3767, 'us': 4717, 'late': 2526, 'refills': 3625, 'eat': 1493, 'shame': 3935, 'love': 2660, 'blond': 550, 'pictur': 3316, 'even': 1607, 'complain': 1039, 'manag': 2712,
# ...

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  57.30366849462452

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)

# %%
export_csv = data_com_buisness.to_csv ("C:/Users/purva.redkar/Downloads/yelp_dataset/yelp_business_merged_preprocessed.csv", index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
print("Naive Bayes f1 Score -> ",f1_score(predictions_NB, Test_Y))
# Out:
# business_id     2490938
# name            2490938
# state           2490938
# stars_x         2490938
# review_count    2490938
# categories      2490938
# review_id       2490938
# user_id         2490938
# stars_y         2490938
# date            2490938
# text            2490938
# text_1          2490938
# dtype: int64

# %%
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=5000, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# Out:
# {'alway': 245, 'enjoy': 1570, 'time': 4504, 'brick': 656, 'hous': 2238, 'food': 1851, 'cocktail': 986, 'never': 2967, 'disappoint': 1370, 'perfect': 3268, 'work': 4935, 'summer': 4313, 'staff': 4182, 'polit': 3373, 'decor': 1269, 'beautiful': 497, 'must': 2910, 'place': 3330, '1st': 34, 'came': 755, 'bc': 489, 'closed': 967, 'burger': 705, 'salad': 3794, 'ice': 2269, 'tea': 4411, '36': 76, '70': 110, 'still': 4232, 'hungry': 2260, 'good': 2018, 'bun': 702, 'liter': 2599, 'got': 2027, '14': 20, 'shoe': 3953, 'string': 4264, 'fri': 1897, 'ridicul': 3724, 'huge': 2248, 'plate': 3339, 'much': 2892, 'empti': 1555, 'space': 4127, 'back': 430, 'wors': 4946, 'servic': 3908, 'ever': 1627, 'andi': 266, 'use': 4720, 'server': 3906, 'job': 2413, 'aw': 413, 'service': 3909, 'waitress': 4809, 'profession': 3468, 'rude': 3771, 'us': 4719, 'late': 2515, 'refills': 3615, 'eat': 1511, 'shame': 3929, 'love': 2640, 'blond': 583, 'pictur': 3302, 'even': 1621, 'complain': 1031, 'manag': 2697, 'didnt': 133
# ...

# %%
# Out:
#               business_id                        name state  stars_x  \
# 0  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 1  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 2  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 3  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"    OH      3.5
#
#    review_count                                         categories  \
# 0           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 1           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 2           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 3           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
# 4           116  American (New);Nightlife;Bars;Sandwiches;Ameri...
#
#                 review_id                 user_id  stars_y        date  \
# 0  rnvu74aNIPn93Z9Ue11Epw  bgtr7jOlALe8ay4g7pnf4A        4  2016-05-05
# ...

# %%
# Out:
# Naive Bayes Accuracy Score ->  52.5

# %%
# Out:
# SVM Accuracy Score ->  57.36666666666667
